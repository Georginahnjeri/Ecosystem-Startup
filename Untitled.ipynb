# %%
import pyodbc
from dotenv import dotenv_values
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
environment_variables = dotenv_values('.env')

# %%
# Get the values for the credentials you set in the '.env' file
server = environment_variables.get("SERVER")
database = environment_variables.get("DATABASE")
username = environment_variables.get("USERNAME")
password = environment_variables.get("PASSWORD")

# %%
# Create a connection string
connection_string = f"DRIVER={{SQL Server}};SERVER={server};DATABASE={database};UID={username};PWD={password};MARS_Connection=yes;MinProtocolVersion=TLSv1.2;"

# %%
# Use the connect method of the pyodbc library and pass in the connection string.
connection = pyodbc.connect(connection_string)

# %%
#
query1 = "SELECT * FROM dbo.LP1_Startup_funding2020"
df_2020 = pd.read_sql(query1, connection)
df_2020.head()
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
# 3         NCOME   2020.0   New Delhi              Escrow
# 4    Gramophone   2016.0      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount     Stage column10
# 0                      Angel investors  200000.0      None     None
# 1                      GSF Accelerator  100000.0  Pre-seed     None
# 2                       Venture Center       NaN  Pre-seed     None
# 3  Venture Catalysts, PointOne Capital  400000.0      None     None
# 4  Siana Capital Management, Info Edge  340000.0      None     None

# %%
#overview of 2020 data
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1055 non-null   object
#  1   Founded        842 non-null    float64
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What_it_does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount         801 non-null    float64
#  8   Stage          591 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 82.6+ KB

# %%
query2 = "SELECT * FROM dbo.LP1_Startup_funding2021"
df_2021 = pd.read_sql(query2, connection)
df_2021.head()
# Out:
#     Company_Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor        Amount         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000          None
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed

# %%
#overview of 2021 data
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What_it_does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount         1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB

# %%
#reading third dataset
df_2019 =  pd.read_csv(r'C:\Users\Georginah/Downloads/startup_funding2019.csv')
df_2019.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %%
#overview of 2019 data
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What it does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount($)      89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB

# %%
df_2018 = pd.read_csv(r'C:\Users\Georginah\Downloads\startup_funding2018.csv')
df_2018.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
#overview of 2018 data
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %% [markdown]
# Observations from the data
# #There are some columns with different names, and need to be changed for uniformity before concatenation
# #The currency in most data is in dollars, with one dataset(2018) with both rupees and dollars.The rupees need to be changed to dollars
# #There is an extra column(column 10) in the 2020 data that we don't really need, so we will delete it

# %% [markdown]
# ***Data Cleaning 2018***

# %%
#view 2018 data
df_2018.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
#rename columns
new_names = {'Company Name':'Company_Brand','Industry':'Sector','Round/Series':'Stage','Location':'HeadQuarter','About Company':'What_it_does'}
df = df_2018.rename(columns=new_names)
df.head()
# Out:
#      Company_Brand                                             Sector  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#       Stage       Amount                       HeadQuarter  \
# 0      Seed       250000       Bangalore, Karnataka, India
# 1      Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2  Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3     Angel      2000000       Noida, Uttar Pradesh, India
# 4      Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                         What_it_does
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
# Add new columns with NaN values

df['Founded'] = '0'
df['Founders'] = 'N/A'
df['Investor'] = 'N/A'

# %%
# Rearrange columns
columns_order = ['Company_Brand','Founded', 'HeadQuarter', 'Sector','What_it_does','Founders','Investor','Amount','Stage']

df = df.reindex(columns=columns_order)

df_2018 = df
df_2018
# Out:
#          Company_Brand Founded                       HeadQuarter  \
# 0      TheCollegeFever       0       Bangalore, Karnataka, India
# 1      Happy Cow Dairy       0        Mumbai, Maharashtra, India
# 2           MyLoanCare       0           Gurgaon, Haryana, India
# 3          PayMe India       0       Noida, Uttar Pradesh, India
# 4             Eunimart       0  Hyderabad, Andhra Pradesh, India
# ..                 ...     ...                               ...
# 521              Udaan       0       Bangalore, Karnataka, India
# 522  Happyeasygo Group       0           Haryana, Haryana, India
# 523             Mombay       0        Mumbai, Maharashtra, India
# 524         Droni Tech       0        Mumbai, Maharashtra, India
# 525            Netmeds       0        Chennai, Tamil Nadu, India
#
#                                                 Sector  \
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 1                                 Agriculture, Farming
# 2     Credit, Financial Services, Lending, Marketplace
# 3                          Financial Services, FinTech
# 4                   E-Commerce Platforms, Retail, SaaS
# ..                                                 ...
# 521   B2B, Business Development, Internet, Marketplace
# 522                                    Tourism, Travel
# 523         Food and Beverage, Food Delivery, Internet
# 524                             Information Technology
# 525         Biotechnology, Health Care, Pharmaceutical
#
#                                           What_it_does Founders Investor  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...      N/A      N/A
# 1    A startup which aggregates milk from dairy far...      N/A      N/A
# 2            Leading Online Loans Marketplace in India      N/A      N/A
# 3    PayMe India is an innovative FinTech organizat...      N/A      N/A
# 4    Eunimart is a one stop solution for merchants ...      N/A      N/A
# ..                                                 ...      ...      ...
# 521  Udaan is a B2B trade platform, designed specif...      N/A      N/A
# 522            HappyEasyGo is an online travel domain.      N/A      N/A
# 523  Mombay is a unique opportunity for housewives ...      N/A      N/A
# 524  Droni Tech manufacture UAVs and develop softwa...      N/A      N/A
# 525       Welcome to India's most convenient pharmacy!      N/A      N/A
#
#           Amount     Stage
# 0         250000      Seed
# 1    ₹40,000,000      Seed
# 2    ₹65,000,000  Series A
# 3        2000000     Angel
# 4              —      Seed
# ..           ...       ...
# 521    225000000  Series C
# 522            —  Series A
# 523         7500      Seed
# 524  ₹35,000,000      Seed
# 525     35000000  Series C
#
# [526 rows x 9 columns]

# %%
#checking info of the df
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  526 non-null    object
#  1   Founded        526 non-null    object
#  2   HeadQuarter    526 non-null    object
#  3   Sector         526 non-null    object
#  4   What_it_does   526 non-null    object
#  5   Founders       526 non-null    object
#  6   Investor       526 non-null    object
#  7   Amount         526 non-null    object
#  8   Stage          526 non-null    object
# dtypes: object(9)
# memory usage: 37.1+ KB

# %%
#cleaning the whole database after rearranging the columns ,inserting the columns and filling the inserted columns with n/a and 0
def swap_non_numeric_with_numeric(df):
    amounts_column = 'Amount'
    stage_column = 'Stage'
    investor_column = 'Investor'
 
    # Function to find non-numeric values in 'Amounts' column
    def find_non_numeric_values():
        non_numeric_dict = {}
        for index, value in df[amounts_column].items():
            try:
                pd.to_numeric(value)
            except ValueError:
                non_numeric_dict[index] = value
        return non_numeric_dict
 
    # Function to find numeric values in 'Stage' column
    def find_numeric_values():
        numeric_dict = {}
        for index, value in df[stage_column].items():
            try:
                numeric_dict[index] = pd.to_numeric(value)
            except ValueError:
                pass  # Ignore non-numeric values
        return numeric_dict
 
    # Find non-numeric values in 'Amounts' column
    non_numeric_values = find_non_numeric_values()
 
    # Find numeric values in 'Stage' column
    numeric_values = find_numeric_values()
 
    # Swap non-numeric values in 'Amounts' with numeric values in 'Stage'
    for index, non_numeric_value in non_numeric_values.items():
        if index in numeric_values:
            df.at[index, amounts_column] = numeric_values[index]
 
    # Swap numeric values in 'Stage' with non-numeric values in 'Amounts'
    for index, numeric_value in numeric_values.items():
        if index in non_numeric_values:
            df.at[index, stage_column] = non_numeric_values[index]
 
    # Function to find numeric values in 'Investor' column
    def find_numeric_values_founders():
        numeric_dict = {}
        for index, value in df[investor_column].items():
            try:
                numeric_dict[index] = pd.to_numeric(value)
            except ValueError:
                pass  # Ignore non-numeric values
        return numeric_dict
 
    # Function to find non-numeric values in 'Amounts' column
    def find_non_numeric_values_founders():
        non_numeric_dict = {}
        for index, value in df[amounts_column].items():
            try:
                pd.to_numeric(value)
            except ValueError:
                non_numeric_dict[index] = value
        return non_numeric_dict
 
    # Find non-numeric values in 'Amounts' column
    non_numeric_values = find_non_numeric_values_founders()
 
    # Find numeric values in 'Founders' column
    numeric_values = find_numeric_values_founders()
 
    # Swap non-numeric values in 'Amounts' with numeric values in 'Founders'
    for index, non_numeric_value in non_numeric_values.items():
        if index in numeric_values:
            df.at[index, amounts_column] = numeric_values[index]
 
    # Swap numeric values in 'Founders' with non-numeric values in 'Amounts'
    for index, numeric_value in numeric_values.items():
        if index in non_numeric_values:
            df.at[index, investor_column] = non_numeric_values[index]
 
    return df
 
 
def strip_dollar_and_comma(df):
    # Assuming column names are 'Amounts' and 'Stage'
    numeric_columns = ['Investor', 'Amount', 'Stage']
 
    # Iterate through numeric columns and strip dollar sign ($) and comma (,)
    for column in numeric_columns:
        df[column] = df[column].replace('[\₹ ,]', '', regex=True)
 
    return df
 
 
def replace_non_numeric_with_zero(df):
    # Assuming column name is 'Amounts'
    amounts_column = 'Amount'
    # Replace non-numeric values in 'Amounts' column with 0
    df[amounts_column] = pd.to_numeric(df[amounts_column], errors='coerce').fillna(0).astype(int)
 
    return df


def fill_null_values(df):
    # Specify the columns to fill with 'N/A'
    columns_to_fill_na = ['HeadQuarter', 'Investor', 'Stage','Sector']
 
    # Fill null values in specified columns with 'N/A'
    df[columns_to_fill_na] = df[columns_to_fill_na].fillna('N/A')

    # Fill null values in 'Founded' with 0   
    df['Founded'] = df['Founded'].fillna(0)

    # Convert 'Founded' values to integers    
    df['Founded'] = df['Founded'].astype(int)
 
    return df


  
 
# Example usage
#data = {'Founders': ['$1,200', '$1,300,000', '', 'D', 'E', 'F', '', 'H', 'J', 'K'],
       # 'Amounts': ['A', 'Undisclosed', '$4,000', '$5,000', 'undisclosed', '$7,000,000', 'Seed', '$4,000', 'series A', '$5,000'],
       # 'Stage': ['Upsparks', 'Series C', 'series c', 'seed', 'seed', 'seed', '$2,000', 'seed', '$3,000', 'series A']}
df = pd.DataFrame(df_2018)
 
# Display the DataFrame before processing
print("DataFrame before processing:")
print(df)
info = df.info()
#print("\n Info before processing")
#print(info)
 
# Call the function to replace NaN values in 'Founders' with "N/A"
df['Founders'] = df['Founders'].fillna('N/A')
 
# Call the function to strip dollar sign and comma from numeric values
df = strip_dollar_and_comma(df)
 
# Display the DataFrame after stripping dollar sign and comma
print("\nDataFrame after stripping dollar sign and comma:")
print(df)
 
# Call the function to swap non-numeric with numeric values
df = swap_non_numeric_with_numeric(df)
 
# Display the DataFrame after swapping Numerical values in Stage with non-numericals in amounts
print("\nDataFrame after swapping numeric in 'Stage' with non-numeric values in 'Amount':")
print(df)
 
# Call the function to swap numeric with non-numeric values in 'Founders'
df = swap_non_numeric_with_numeric(df)
 
# Display the DataFrame after swapping numeric with non-numeric values in 'Founders'
#print("\nDataFrame after swapping numeric in 'Founders' with non-numeric values in 'Amount':")
#print(df)
# Call the function to fill null values with 'N/A'
df = fill_null_values(df)
 # Display the DataFrame after filling null values
print("\nDataFrame after filling null values with 'N/A':")

print(df)
# Call the function to replace non-numeric values in 'Amounts' with 0
df = replace_non_numeric_with_zero(df)

# Call the function to fill null values in  'Founded' with 0
df = fill_null_values(df) 
# Display the DataFrame after filling null values
#print("\nDataFrame after filling null values with 'N/A' and 'Founded' with 0:")
#print(df)

 
 
# Display the DataFrame after replacing non-numeric values with 0
#My amounts column should have all numerics
#print("\nDataFrame after replacing non-numeric values with 0 :")
print("\nDataFrame after processing:")
cleandata_2018=df
cleandata_2018.head(10)
# Out:
# DataFrame before processing:
#          Company_Brand Founded                       HeadQuarter  \
# 0      TheCollegeFever       0       Bangalore, Karnataka, India
# 1      Happy Cow Dairy       0        Mumbai, Maharashtra, India
# 2           MyLoanCare       0           Gurgaon, Haryana, India
# 3          PayMe India       0       Noida, Uttar Pradesh, India
# 4             Eunimart       0  Hyderabad, Andhra Pradesh, India
# ..                 ...     ...                               ...
# 521              Udaan       0       Bangalore, Karnataka, India
# 522  Happyeasygo Group       0           Haryana, Haryana, India
# 523             Mombay       0        Mumbai, Maharashtra, India
# 524         Droni Tech       0        Mumbai, Maharashtra, India
# 525            Netmeds       0        Chennai, Tamil Nadu, India
#
#                                                 Sector  \
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 1                                 Agriculture, Farming
# 2     Credit, Financial Services, Lending, Marketplace
# 3                          Financial Services, FinTech
# 4                   E-Commerce Platforms, Retail, SaaS
# ..                                                 ...
# 521   B2B, Business Development, Internet, Marketplace
# 522                                    Tourism, Travel
# 523         Food and Beverage, Food Delivery, Internet
# 524                             Information Technology
# 525         Biotechnology, Health Care, Pharmaceutical
#
#                                           What_it_does Founders Investor  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...      N/A      N/A
# 1    A startup which aggregates milk from dairy far...      N/A      N/A
# 2            Leading Online Loans Marketplace in India      N/A      N/A
# 3    PayMe India is an innovative FinTech organizat...      N/A      N/A
# 4    Eunimart is a one stop solution for merchants ...      N/A      N/A
# ..                                                 ...      ...      ...
# 521  Udaan is a B2B trade platform, designed specif...      N/A      N/A
# 522            HappyEasyGo is an online travel domain.      N/A      N/A
# 523  Mombay is a unique opportunity for housewives ...      N/A      N/A
# 524  Droni Tech manufacture UAVs and develop softwa...      N/A      N/A
# 525       Welcome to India's most convenient pharmacy!      N/A      N/A
#
#           Amount     Stage
# 0         250000      Seed
# 1    ₹40,000,000      Seed
# 2    ₹65,000,000  Series A
# 3        2000000     Angel
# 4              —      Seed
# ..           ...       ...
# 521    225000000  Series C
# 522            —  Series A
# 523         7500      Seed
# 524  ₹35,000,000      Seed
# 525     35000000  Series C
#
# [526 rows x 9 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  526 non-null    object
#  1   Founded        526 non-null    object
#  2   HeadQuarter    526 non-null    object
#  3   Sector         526 non-null    object
#  4   What_it_does   526 non-null    object
#  5   Founders       526 non-null    object
#  6   Investor       526 non-null    object
#  7   Amount         526 non-null    object
#  8   Stage          526 non-null    object
# dtypes: object(9)
# memory usage: 37.1+ KB
#
# DataFrame after stripping dollar sign and comma:
#          Company_Brand Founded                       HeadQuarter  \
# 0      TheCollegeFever       0       Bangalore, Karnataka, India
# 1      Happy Cow Dairy       0        Mumbai, Maharashtra, India
# 2           MyLoanCare       0           Gurgaon, Haryana, India
# 3          PayMe India       0       Noida, Uttar Pradesh, India
# 4             Eunimart       0  Hyderabad, Andhra Pradesh, India
# ..                 ...     ...                               ...
# 521              Udaan       0       Bangalore, Karnataka, India
# 522  Happyeasygo Group       0           Haryana, Haryana, India
# 523             Mombay       0        Mumbai, Maharashtra, India
# 524         Droni Tech       0        Mumbai, Maharashtra, India
# 525            Netmeds       0        Chennai, Tamil Nadu, India
#
#                                                 Sector  \
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 1                                 Agriculture, Farming
# 2     Credit, Financial Services, Lending, Marketplace
# 3                          Financial Services, FinTech
# 4                   E-Commerce Platforms, Retail, SaaS
# ..                                                 ...
# 521   B2B, Business Development, Internet, Marketplace
# 522                                    Tourism, Travel
# 523         Food and Beverage, Food Delivery, Internet
# 524                             Information Technology
# 525         Biotechnology, Health Care, Pharmaceutical
#
#                                           What_it_does Founders Investor  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...      N/A      N/A
# 1    A startup which aggregates milk from dairy far...      N/A      N/A
# 2            Leading Online Loans Marketplace in India      N/A      N/A
# 3    PayMe India is an innovative FinTech organizat...      N/A      N/A
# 4    Eunimart is a one stop solution for merchants ...      N/A      N/A
# ..                                                 ...      ...      ...
# 521  Udaan is a B2B trade platform, designed specif...      N/A      N/A
# 522            HappyEasyGo is an online travel domain.      N/A      N/A
# 523  Mombay is a unique opportunity for housewives ...      N/A      N/A
# 524  Droni Tech manufacture UAVs and develop softwa...      N/A      N/A
# 525       Welcome to India's most convenient pharmacy!      N/A      N/A
#
#         Amount    Stage
# 0       250000     Seed
# 1     40000000     Seed
# 2     65000000  SeriesA
# 3      2000000    Angel
# 4            —     Seed
# ..         ...      ...
# 521  225000000  SeriesC
# 522          —  SeriesA
# 523       7500     Seed
# 524   35000000     Seed
# 525   35000000  SeriesC
#
# [526 rows x 9 columns]
#
# DataFrame after swapping numeric in 'Stage' with non-numeric values in 'Amount':
#          Company_Brand Founded                       HeadQuarter  \
# 0      TheCollegeFever       0       Bangalore, Karnataka, India
# 1      Happy Cow Dairy       0        Mumbai, Maharashtra, India
# 2           MyLoanCare       0           Gurgaon, Haryana, India
# 3          PayMe India       0       Noida, Uttar Pradesh, India
# 4             Eunimart       0  Hyderabad, Andhra Pradesh, India
# ..                 ...     ...                               ...
# 521              Udaan       0       Bangalore, Karnataka, India
# 522  Happyeasygo Group       0           Haryana, Haryana, India
# 523             Mombay       0        Mumbai, Maharashtra, India
# 524         Droni Tech       0        Mumbai, Maharashtra, India
# 525            Netmeds       0        Chennai, Tamil Nadu, India
#
#                                                 Sector  \
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 1                                 Agriculture, Farming
# 2     Credit, Financial Services, Lending, Marketplace
# 3                          Financial Services, FinTech
# 4                   E-Commerce Platforms, Retail, SaaS
# ..                                                 ...
# 521   B2B, Business Development, Internet, Marketplace
# 522                                    Tourism, Travel
# 523         Food and Beverage, Food Delivery, Internet
# 524                             Information Technology
# 525         Biotechnology, Health Care, Pharmaceutical
#
#                                           What_it_does Founders Investor  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...      N/A      N/A
# 1    A startup which aggregates milk from dairy far...      N/A      N/A
# 2            Leading Online Loans Marketplace in India      N/A      N/A
# 3    PayMe India is an innovative FinTech organizat...      N/A      N/A
# 4    Eunimart is a one stop solution for merchants ...      N/A      N/A
# ..                                                 ...      ...      ...
# 521  Udaan is a B2B trade platform, designed specif...      N/A      N/A
# 522            HappyEasyGo is an online travel domain.      N/A      N/A
# 523  Mombay is a unique opportunity for housewives ...      N/A      N/A
# 524  Droni Tech manufacture UAVs and develop softwa...      N/A      N/A
# 525       Welcome to India's most convenient pharmacy!      N/A      N/A
#
#         Amount    Stage
# 0       250000     Seed
# 1     40000000     Seed
# 2     65000000  SeriesA
# 3      2000000    Angel
# 4            —     Seed
# ..         ...      ...
# 521  225000000  SeriesC
# 522          —  SeriesA
# 523       7500     Seed
# 524   35000000     Seed
# 525   35000000  SeriesC
#
# [526 rows x 9 columns]
#
# DataFrame after filling null values with 'N/A':
#          Company_Brand  Founded                       HeadQuarter  \
# 0      TheCollegeFever        0       Bangalore, Karnataka, India
# 1      Happy Cow Dairy        0        Mumbai, Maharashtra, India
# 2           MyLoanCare        0           Gurgaon, Haryana, India
# 3          PayMe India        0       Noida, Uttar Pradesh, India
# 4             Eunimart        0  Hyderabad, Andhra Pradesh, India
# ..                 ...      ...                               ...
# 521              Udaan        0       Bangalore, Karnataka, India
# 522  Happyeasygo Group        0           Haryana, Haryana, India
# 523             Mombay        0        Mumbai, Maharashtra, India
# 524         Droni Tech        0        Mumbai, Maharashtra, India
# 525            Netmeds        0        Chennai, Tamil Nadu, India
#
#                                                 Sector  \
# 0    Brand Marketing, Event Promotion, Marketing, S...
# 1                                 Agriculture, Farming
# 2     Credit, Financial Services, Lending, Marketplace
# 3                          Financial Services, FinTech
# 4                   E-Commerce Platforms, Retail, SaaS
# ..                                                 ...
# 521   B2B, Business Development, Internet, Marketplace
# 522                                    Tourism, Travel
# 523         Food and Beverage, Food Delivery, Internet
# 524                             Information Technology
# 525         Biotechnology, Health Care, Pharmaceutical
#
#                                           What_it_does Founders Investor  \
# 0    TheCollegeFever is a hub for fun, fiesta and f...      N/A      N/A
# 1    A startup which aggregates milk from dairy far...      N/A      N/A
# 2            Leading Online Loans Marketplace in India      N/A      N/A
# 3    PayMe India is an innovative FinTech organizat...      N/A      N/A
# 4    Eunimart is a one stop solution for merchants ...      N/A      N/A
# ..                                                 ...      ...      ...
# 521  Udaan is a B2B trade platform, designed specif...      N/A      N/A
# 522            HappyEasyGo is an online travel domain.      N/A      N/A
# 523  Mombay is a unique opportunity for housewives ...      N/A      N/A
# 524  Droni Tech manufacture UAVs and develop softwa...      N/A      N/A
# 525       Welcome to India's most convenient pharmacy!      N/A      N/A
#
#         Amount    Stage
# 0       250000     Seed
# 1     40000000     Seed
# 2     65000000  SeriesA
# 3      2000000    Angel
# 4            —     Seed
# ..         ...      ...
# 521  225000000  SeriesC
# 522          —  SeriesA
# 523       7500     Seed
# 524   35000000     Seed
# 525   35000000  SeriesC
#
# [526 rows x 9 columns]
#
# DataFrame after processing:
#         Company_Brand  Founded                       HeadQuarter  \
# 0     TheCollegeFever        0       Bangalore, Karnataka, India
# 1     Happy Cow Dairy        0        Mumbai, Maharashtra, India
# 2          MyLoanCare        0           Gurgaon, Haryana, India
# 3         PayMe India        0       Noida, Uttar Pradesh, India
# 4            Eunimart        0  Hyderabad, Andhra Pradesh, India
# 5              Hasura        0       Bengaluru, Karnataka, India
# 6           Tripshelf        0             Kalkaji, Delhi, India
# 7        Hyperdata.IO        0  Hyderabad, Andhra Pradesh, India
# 8        Freightwalla        0        Mumbai, Maharashtra, India
# 9  Microchip Payments        0       Bangalore, Karnataka, India
#
#                                               Sector  \
# 0  Brand Marketing, Event Promotion, Marketing, S...
# 1                               Agriculture, Farming
# 2   Credit, Financial Services, Lending, Marketplace
# 3                        Financial Services, FinTech
# 4                 E-Commerce Platforms, Retail, SaaS
# 5                   Cloud Infrastructure, PaaS, SaaS
# 6                     Internet, Leisure, Marketplace
# 7                                    Market Research
# 8       Information Services, Information Technology
# 9                                    Mobile Payments
#
#                                         What_it_does Founders Investor  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...      N/A      N/A
# 1  A startup which aggregates milk from dairy far...      N/A      N/A
# 2          Leading Online Loans Marketplace in India      N/A      N/A
# 3  PayMe India is an innovative FinTech organizat...      N/A      N/A
# 4  Eunimart is a one stop solution for merchants ...      N/A      N/A
# 5  Hasura is a platform that allows developers to...      N/A      N/A
# 6  Tripshelf is an online market place for holida...      N/A      N/A
# 7  Hyperdata combines advanced machine learning w...      N/A      N/A
# 8  Freightwalla is an international forwarder tha...      N/A      N/A
# 9  Microchip payments is a mobile-based payment a...      N/A      N/A
#
#      Amount    Stage
# 0    250000     Seed
# 1  40000000     Seed
# 2  65000000  SeriesA
# 3   2000000    Angel
# 4         0     Seed
# 5   1600000     Seed
# 6  16000000     Seed
# 7  50000000    Angel
# 8         0     Seed
# 9         0     Seed

# %%
# checking the null values after cleaning 
cleandata_2018.isna().sum()
# Out:
# Company_Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# What_it_does     0
# Founders         0
# Investor         0
# Amount           0
# Stage            0
# dtype: int64

# %% [markdown]
# ***cleaning 2019***

# %%
#viewing 2019 data
df_2019.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)  \
# 0                               Sixth Sense Ventures    $6,300,000
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %%
# Renaming columns
df_2019.rename(columns={'Amount($)': 'Amount','Company/Brand':'Company_Brand','What it does': 'What_it_does'}, inplace=True)
df_2019
# Out:
#       Company_Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What_it_does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# 2             It aims to make learning fun via games.
# 3               Provides interior designing solutions
# 4   It is a seed company engaged in production, pr...
# ..                                                ...
# 84  It connects client requirements to their suppl...
# 85                Provides rooms for comfortable stay
# 86  Find automobile repair and maintenance service...
# 87                                Online car retailer
# 88              Organised Non-Banking Finance Company
#
#                                              Founders  \
# 0                                  Shantanu Deshpande
# 1               Adamas Belva Syah Devara, Iman Usman.
# 2                                       Jatin Solanki
# 3                        Srikanth Iyer, Rama Harinath
# 4                              Narayana Reddy Punyala
# ..                                                ...
# 84                    Aaditya Sharda, Souvik Sengupta
# 85                                     Ritesh Agarwal
# 86  Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh...
# 87  Niraj Singh, Ramanshu Mahaur, Ganesh Pawar, Mo...
# 88                                     Rajendra Setia
#
#                                              Investor        Amount  \
# 0                                Sixth Sense Ventures    $6,300,000
# 1                                    General Atlantic  $150,000,000
# 2      Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3   Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4            Innovation in Food and Agriculture (IFA)    $6,000,000
# ..                                                ...           ...
# 84  Tiger Global, Nexus Venture Partners, Accel Pa...   $20,000,000
# 85  MyPreferred Transformation, Avendus Finance, S...  $693,000,000
# 86                                    Sequoia Capital    $5,000,000
# 87  Norwest Venture Partners, General Catalyst, Fu...   $50,000,000
# 88     TPG, Norwest Venture Partners, Evolvence India   $33,000,000
#
#             Stage
# 0             NaN
# 1        Series C
# 2   Fresh funding
# 3        Series D
# 4             NaN
# ..            ...
# 84       Series A
# 85            NaN
# 86       Series B
# 87            NaN
# 88            NaN
#
# [89 rows x 9 columns]

# %%
def swap_non_numeric_with_numeric(df):
    amounts_column = 'Amount'
    stage_column = 'Stage'
    investor_column = 'Investor'
 
    # Function to find non-numeric values in 'Amounts' column
    def find_non_numeric_values():
        non_numeric_dict = {}
        for index, value in df[amounts_column].items():
            try:
                pd.to_numeric(value)
            except ValueError:
                non_numeric_dict[index] = value
        return non_numeric_dict
 
    # Function to find numeric values in 'Stage' column
    def find_numeric_values():
        numeric_dict = {}
        for index, value in df[stage_column].items():
            try:
                numeric_dict[index] = pd.to_numeric(value)
            except ValueError:
                pass  # Ignore non-numeric values
        return numeric_dict
 
    # Find non-numeric values in 'Amounts' column
    non_numeric_values = find_non_numeric_values()
 
    # Find numeric values in 'Stage' column
    numeric_values = find_numeric_values()
 
    # Swap non-numeric values in 'Amounts' with numeric values in 'Stage'
    for index, non_numeric_value in non_numeric_values.items():
        if index in numeric_values:
            df.at[index, amounts_column] = numeric_values[index]
 
    # Swap numeric values in 'Stage' with non-numeric values in 'Amounts'
    for index, numeric_value in numeric_values.items():
        if index in non_numeric_values:
            df.at[index, stage_column] = non_numeric_values[index]
 
    # Function to find numeric values in 'Investor' column
    def find_numeric_values_founders():
        numeric_dict = {}
        for index, value in df[investor_column].items():
            try:
                numeric_dict[index] = pd.to_numeric(value)
            except ValueError:
                pass  # Ignore non-numeric values
        return numeric_dict
 
    # Function to find non-numeric values in 'Amounts' column
    def find_non_numeric_values_founders():
        non_numeric_dict = {}
        for index, value in df[amounts_column].items():
            try:
                pd.to_numeric(value)
            except ValueError:
                non_numeric_dict[index] = value
        return non_numeric_dict
 
    # Find non-numeric values in 'Amounts' column
    non_numeric_values = find_non_numeric_values_founders()
 
    # Find numeric values in 'Founders' column
    numeric_values = find_numeric_values_founders()
 
    # Swap non-numeric values in 'Amounts' with numeric values in 'Founders'
    for index, non_numeric_value in non_numeric_values.items():
        if index in numeric_values:
            df.at[index, amounts_column] = numeric_values[index]
 
    # Swap numeric values in 'Founders' with non-numeric values in 'Amounts'
    for index, numeric_value in numeric_values.items():
        if index in non_numeric_values:
            df.at[index, investor_column] = non_numeric_values[index]
 
    return df
 
 
def strip_dollar_and_comma(df):
    # Assuming column names are 'Amounts' and 'Stage'
    numeric_columns = ['Investor', 'Amount', 'Stage']
 
    # Iterate through numeric columns and strip dollar sign ($) and comma (,)
    for column in numeric_columns:
        df[column] = df[column].replace('[\$ ,]', '', regex=True)
 
    return df
 
 
def replace_non_numeric_with_zero(df):
    # Assuming column name is 'Amounts'
    amounts_column = 'Amount'
    # Replace non-numeric values in 'Amounts' column with 0
    df[amounts_column] = pd.to_numeric(df[amounts_column], errors='coerce').fillna(0).astype(int)
 
    return df


def fill_null_values(df):
    # Specify the columns to fill with 'N/A'
    columns_to_fill_na = ['HeadQuarter', 'Investor', 'Stage','Sector']
 
    # Fill null values in specified columns with 'N/A'
    df[columns_to_fill_na] = df[columns_to_fill_na].fillna('N/A')

    # Fill null values in 'Founded' with 0   
    df['Founded'] = df['Founded'].fillna(0)

    # Convert 'Founded' values to integers    
    df['Founded'] = df['Founded'].astype(int)
 
    return df


  
 
# Example usage
#data = {'Founders': ['$1,200', '$1,300,000', '', 'D', 'E', 'F', '', 'H', 'J', 'K'],
       # 'Amounts': ['A', 'Undisclosed', '$4,000', '$5,000', 'undisclosed', '$7,000,000', 'Seed', '$4,000', 'series A', '$5,000'],
       # 'Stage': ['Upsparks', 'Series C', 'series c', 'seed', 'seed', 'seed', '$2,000', 'seed', '$3,000', 'series A']}
df = pd.DataFrame(df_2019)
 
# Display the DataFrame before processing
print("DataFrame before processing:")
print(df)
info = df.info()
#print("\n Info before processing")
#print(info)
 
# Call the function to replace NaN values in 'Founders' with "N/A"
df['Founders'] = df['Founders'].fillna('N/A')
 
# Call the function to strip dollar sign and comma from numeric values
df = strip_dollar_and_comma(df)
 
# Display the DataFrame after stripping dollar sign and comma
#print("\nDataFrame after stripping dollar sign and comma:")
#print(df)
 
# Call the function to swap non-numeric with numeric values
df = swap_non_numeric_with_numeric(df)
 
# Display the DataFrame after swapping Numerical values in Stage with non-numericals in amounts
#print("\nDataFrame after swapping numeric in 'Stage' with non-numeric values in 'Amount':")
#print(df)
 
# Call the function to swap numeric with non-numeric values in 'Founders'
df = swap_non_numeric_with_numeric(df)
 
# Display the DataFrame after swapping numeric with non-numeric values in 'Founders'
#print("\nDataFrame after swapping numeric in 'Founders' with non-numeric values in 'Amount':")
#print(df)
# Call the function to fill null values with 'N/A'
df = fill_null_values(df)
 # Display the DataFrame after filling null values
print("\nDataFrame after filling null values with 'N/A':")

print(df)
# Call the function to replace non-numeric values in 'Amounts' with 0
df = replace_non_numeric_with_zero(df)

# Call the function to fill null values in  'Founded' with 0
df = fill_null_values(df) 
# Display the DataFrame after filling null values
#print("\nDataFrame after filling null values with 'N/A' and 'Founded' with 0:")
#print(df)

 
 
# Display the DataFrame after replacing non-numeric values with 0
#My amounts column should have all numerics
#print("\nDataFrame after replacing non-numeric values with 0 :")
print("\nDataFrame after processing:")
cleandata_2019=df
cleandata_2019.head(10)
# Out:
# DataFrame before processing:
#       Company_Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What_it_does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# 2             It aims to make learning fun via games.
# 3               Provides interior designing solutions
# 4   It is a seed company engaged in production, pr...
# ..                                                ...
# 84  It connects client requirements to their suppl...
# 85                Provides rooms for comfortable stay
# 86  Find automobile repair and maintenance service...
# 87                                Online car retailer
# 88              Organised Non-Banking Finance Company
#
#                                              Founders  \
# 0                                  Shantanu Deshpande
# 1               Adamas Belva Syah Devara, Iman Usman.
# 2                                       Jatin Solanki
# 3                        Srikanth Iyer, Rama Harinath
# 4                              Narayana Reddy Punyala
# ..                                                ...
# 84                    Aaditya Sharda, Souvik Sengupta
# 85                                     Ritesh Agarwal
# 86  Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh...
# 87  Niraj Singh, Ramanshu Mahaur, Ganesh Pawar, Mo...
# 88                                     Rajendra Setia
#
#                                              Investor        Amount  \
# 0                                Sixth Sense Ventures    $6,300,000
# 1                                    General Atlantic  $150,000,000
# 2      Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3   Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4            Innovation in Food and Agriculture (IFA)    $6,000,000
# ..                                                ...           ...
# 84  Tiger Global, Nexus Venture Partners, Accel Pa...   $20,000,000
# 85  MyPreferred Transformation, Avendus Finance, S...  $693,000,000
# 86                                    Sequoia Capital    $5,000,000
# 87  Norwest Venture Partners, General Catalyst, Fu...   $50,000,000
# 88     TPG, Norwest Venture Partners, Evolvence India   $33,000,000
#
#             Stage
# 0             NaN
# 1        Series C
# 2   Fresh funding
# 3        Series D
# 4             NaN
# ..            ...
# 84       Series A
# 85            NaN
# 86       Series B
# 87            NaN
# 88            NaN
#
# [89 rows x 9 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  89 non-null     object
#  1   Founded        60 non-null     float64
#  2   HeadQuarter    70 non-null     object
#  3   Sector         84 non-null     object
#  4   What_it_does   89 non-null     object
#  5   Founders       86 non-null     object
#  6   Investor       89 non-null     object
#  7   Amount         89 non-null     object
#  8   Stage          43 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 6.4+ KB
#
# DataFrame after filling null values with 'N/A':
#       Company_Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving        0         N/A                Ecommerce
# 1         Ruangguru     2014      Mumbai                   Edtech
# 2          Eduisfun        0      Mumbai                   Edtech
# 3          HomeLane     2014     Chennai          Interior design
# 4          Nu Genes     2004   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market        0      Mumbai                Infratech
# 85              Oyo     2013    Gurugram              Hospitality
# 86       GoMechanic     2016       Delhi  Automobile & Technology
# 87           Spinny     2015       Delhi               Automobile
# 88  Ess Kay Fincorp        0   Rajasthan                  Banking
#
#                                          What_it_does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# 2             It aims to make learning fun via games.
# 3               Provides interior designing solutions
# 4   It is a seed company engaged in production, pr...
# ..                                                ...
# 84  It connects client requirements to their suppl...
# 85                Provides rooms for comfortable stay
# 86  Find automobile repair and maintenance service...
# 87                                Online car retailer
# 88              Organised Non-Banking Finance Company
#
#                                              Founders  \
# 0                                  Shantanu Deshpande
# 1               Adamas Belva Syah Devara, Iman Usman.
# 2                                       Jatin Solanki
# 3                        Srikanth Iyer, Rama Harinath
# 4                              Narayana Reddy Punyala
# ..                                                ...
# 84                    Aaditya Sharda, Souvik Sengupta
# 85                                     Ritesh Agarwal
# 86  Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh...
# 87  Niraj Singh, Ramanshu Mahaur, Ganesh Pawar, Mo...
# 88                                     Rajendra Setia
#
#                                              Investor     Amount         Stage
# 0                                  SixthSenseVentures    6300000           N/A
# 1                                     GeneralAtlantic  150000000       SeriesC
# 2             DeepakParekhAmitabhBachchanPiyushPandey   28000000  Freshfunding
# 3          EvolvenceIndiaFund(EIF)PidiliteGroupFJLabs   30000000       SeriesD
# 4                 InnovationinFoodandAgriculture(IFA)    6000000           N/A
# ..                                                ...        ...           ...
# 84  TigerGlobalNexusVenturePartnersAccelPartnersDh...   20000000       SeriesA
# 85    MyPreferredTransformationAvendusFinanceSoftBank  693000000           N/A
# 86                                     SequoiaCapital    5000000       SeriesB
# 87  NorwestVenturePartnersGeneralCatalystFundament...   50000000           N/A
# 88            TPGNorwestVenturePartnersEvolvenceIndia   33000000           N/A
#
# [89 rows x 9 columns]
#
# DataFrame after processing:
#     Company_Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving        0         N/A        Ecommerce
# 1       Ruangguru     2014      Mumbai           Edtech
# 2        Eduisfun        0      Mumbai           Edtech
# 3        HomeLane     2014     Chennai  Interior design
# 4        Nu Genes     2004   Telangana         AgriTech
# 5        FlytBase        0        Pune       Technology
# 6           Finly        0   Bangalore             SaaS
# 7        Kratikal     2013       Noida       Technology
# 8       Quantiphi        0         N/A        AI & Tech
# 9        Lenskart     2010       Delhi       E-commerce
#
#                                         What_it_does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
# 5                        A drone automation platform
# 6  It builds software products that makes work si...
# 7  It is a product-based cybersecurity solutions ...
# 8  It is an AI and big data services company prov...
# 9                            It is a eyewear company
#
#                                           Founders  \
# 0                               Shantanu Deshpande
# 1            Adamas Belva Syah Devara, Iman Usman.
# 2                                    Jatin Solanki
# 3                     Srikanth Iyer, Rama Harinath
# 4                           Narayana Reddy Punyala
# 5                                      Nitin Gupta
# 6                        Vivek AG, Veekshith C Rai
# 7  Pavan Kushwaha, Paratosh Bansal, Dip Jung Thapa
# 8                                   Renuka Ramnath
# 9     Peyush Bansal, Amit Chaudhary, Sumeet Kapahi
#
#                                             Investor     Amount         Stage
# 0                                 SixthSenseVentures    6300000           N/A
# 1                                    GeneralAtlantic  150000000       SeriesC
# 2            DeepakParekhAmitabhBachchanPiyushPandey   28000000  Freshfunding
# 3         EvolvenceIndiaFund(EIF)PidiliteGroupFJLabs   30000000       SeriesD
# 4                InnovationinFoodandAgriculture(IFA)    6000000           N/A
# 5                                        Undisclosed          0   Undisclosed
# 6  SocialCapitalAngelListIndiaGembaCapitalOmphalo...          0   Undisclosed
# 7                GildaVCArtVentureRajeevChitrabhanu.    1000000    PreseriesA
# 8                  MultiplesAlternateAssetManagement   20000000       SeriesA
# 9                                           SoftBank  275000000       SeriesG

# %%
#checking the cleaned data
cleandata_2019.isnull().sum()
# Out:
# Company_Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# What_it_does     0
# Founders         0
# Investor         0
# Amount           0
# Stage            0
# dtype: int64

# %% [markdown]
# **Cleaning 2020 data**

# %%
# Viewing the data 
df_2020.head()
# Out:
#   Company_Brand  Founded HeadQuarter              Sector  \
# 0    Aqgromalin   2019.0     Chennai            AgriTech
# 1      Krayonnz   2019.0   Bangalore              EdTech
# 2  PadCare Labs   2018.0        Pune  Hygiene management
# 3         NCOME   2020.0   New Delhi              Escrow
# 4    Gramophone   2016.0      Indore            AgriTech
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount     Stage column10
# 0                      Angel investors  200000.0      None     None
# 1                      GSF Accelerator  100000.0  Pre-seed     None
# 2                       Venture Center       NaN  Pre-seed     None
# 3  Venture Catalysts, PointOne Capital  400000.0      None     None
# 4  Siana Capital Management, Info Edge  340000.0      None     None

# %%
# showing the data type 
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1055 non-null   object
#  1   Founded        842 non-null    float64
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What_it_does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount         801 non-null    float64
#  8   Stage          591 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 82.6+ KB

# %%
# checking the frequency count of missing values 
df_2020.apply(lambda X:sum(X.isnull()))
# Out:
# Company_Brand       0
# Founded           213
# HeadQuarter        94
# Sector             13
# What_it_does        0
# Founders           12
# Investor           38
# Amount            254
# Stage             464
# column10         1053
# dtype: int64

# %%
def swap_non_numeric_with_numeric(df):
    amounts_column = 'Amount'
    stage_column = 'Stage'
    investor_column = 'Investor'

 
    # Function to find non-numeric values in 'Amounts' column
    def find_non_numeric_values():
        non_numeric_dict = {}
        for index, value in df[amounts_column].items():
            try:
                pd.to_numeric(value)
            except ValueError:
                non_numeric_dict[index] = value
        return non_numeric_dict
 
    # Function to find numeric values in 'Stage' column
    def find_numeric_values():
        numeric_dict = {}
        for index, value in df[stage_column].items():
            try:
                numeric_dict[index] = pd.to_numeric(value)
            except ValueError:
                pass  # Ignore non-numeric values
        return numeric_dict
 
    # Find non-numeric values in 'Amounts' column
    non_numeric_values = find_non_numeric_values()
 
    # Find numeric values in 'Stage' column
    numeric_values = find_numeric_values()
 
    # Swap non-numeric values in 'Amounts' with numeric values in 'Stage'
    for index, non_numeric_value in non_numeric_values.items():
        if index in numeric_values:
            df.at[index, amounts_column] = numeric_values[index]
 
    # Swap numeric values in 'Stage' with non-numeric values in 'Amounts'
    for index, numeric_value in numeric_values.items():
        if index in non_numeric_values:
            df.at[index, stage_column] = non_numeric_values[index]
 
    # Function to find numeric values in 'Investor' column
    def find_numeric_values_founders():
        numeric_dict = {}
        for index, value in df[investor_column].items():
            try:
                numeric_dict[index] = pd.to_numeric(value)
            except ValueError:
                pass  # Ignore non-numeric values
        return numeric_dict
 
    # Function to find non-numeric values in 'Amounts' column
    def find_non_numeric_values_founders():
        non_numeric_dict = {}
        for index, value in df[amounts_column].items():
            try:
                pd.to_numeric(value)
            except ValueError:
                non_numeric_dict[index] = value
        return non_numeric_dict
 
    # Find non-numeric values in 'Amounts' column
    non_numeric_values = find_non_numeric_values_founders()
 
    # Find numeric values in 'Founders' column
    numeric_values = find_numeric_values_founders()
 
    # Swap non-numeric values in 'Amounts' with numeric values in 'Founders'
    for index, non_numeric_value in non_numeric_values.items():
        if index in numeric_values:
            df.at[index, amounts_column] = numeric_values[index]
 
    # Swap numeric values in 'Founders' with non-numeric values in 'Amounts'
    for index, numeric_value in numeric_values.items():
        if index in non_numeric_values:
            df.at[index, investor_column] = non_numeric_values[index]
 
    return df
 
 
def strip_dollar_and_comma(df):
    # Assuming column names are 'Amounts' and 'Stage'
    numeric_columns = ['Investor', 'Amount', 'Stage']
 
    # Iterate through numeric columns and strip dollar sign ($) and comma (,)
    for column in numeric_columns:
        df[column] = df[column].replace('[\$]', '', regex=True)
 
    return df
 
 
def replace_non_numeric_with_zero(df):
    # Assuming column name is 'Amounts'
    amounts_column = 'Amount'
    # Replace non-numeric values in 'Amounts' column with 0
    df[amounts_column] = pd.to_numeric(df[amounts_column], errors='coerce').fillna(0).astype(int)
 
    return df


def fill_null_values(df):
    # Specify the columns to fill with 'N/A'
    columns_to_fill_na = ['HeadQuarter', 'Investor', 'Stage','Sector']
 
    # Fill null values in specified columns with 'N/A'
    df[columns_to_fill_na] = df[columns_to_fill_na].fillna('N/A')

    # Fill null values in 'Founded' with 0   
    df['Founded'] = df['Founded'].fillna(0)

    # Convert 'Founded' values to integers    
    df['Founded'] = df['Founded'].astype(int)
 
    return df


  
 
# Example usage
#data = {'Founders': ['$1,200', '$1,300,000', '', 'D', 'E', 'F', '', 'H', 'J', 'K'],
       # 'Amounts': ['A', 'Undisclosed', '$4,000', '$5,000', 'undisclosed', '$7,000,000', 'Seed', '$4,000', 'series A', '$5,000'],
       # 'Stage': ['Upsparks', 'Series C', 'series c', 'seed', 'seed', 'seed', '$2,000', 'seed', '$3,000', 'series A']}
df = pd.DataFrame(df_2020)
 
# Display the DataFrame before processing
print("DataFrame before processing:")
print(df)
info = df.info()
#print("\n Info before processing")
#print(info)
 
# Call the function to replace NaN values in 'Founders' with "N/A"
df['Founders'] = df['Founders'].fillna('N/A')
 
# Call the function to strip dollar sign and comma from numeric values
df = strip_dollar_and_comma(df)
 
# Display the DataFrame after stripping dollar sign and comma
#print("\nDataFrame after stripping dollar sign and comma:")
#print(df)
 
# Call the function to swap non-numeric with numeric values
df = swap_non_numeric_with_numeric(df)
 
# Display the DataFrame after swapping Numerical values in Stage with non-numericals in amounts
#print("\nDataFrame after swapping numeric in 'Stage' with non-numeric values in 'Amount':")
#print(df)
 
# Call the function to swap numeric with non-numeric values in 'Founders'
df = swap_non_numeric_with_numeric(df)
 
# Display the DataFrame after swapping numeric with non-numeric values in 'Founders'
#print("\nDataFrame after swapping numeric in 'Founders' with non-numeric values in 'Amount':")
#print(df)
# Call the function to fill null values with 'N/A'
df = fill_null_values(df)
 # Display the DataFrame after filling null values
print("\nDataFrame after filling null values with 'N/A':")

print(df)
# Call the function to replace non-numeric values in 'Amounts' with 0
df = replace_non_numeric_with_zero(df)

# Call the function to fill null values in  'Founded' with 0
df = fill_null_values(df) 
# Display the DataFrame after filling null values
#print("\nDataFrame after filling null values with 'N/A' and 'Founded' with 0:")
#print(df)

 
 
# Display the DataFrame after replacing non-numeric values with 0
#My amounts column should have all numerics
#print("\nDataFrame after replacing non-numeric values with 0 :")
print("\nDataFrame after processing:")
cleandata_2020=df
cleandata_2020.head(10)
# Out:
# DataFrame before processing:
#      Company_Brand  Founded HeadQuarter              Sector  \
# 0       Aqgromalin   2019.0     Chennai            AgriTech
# 1         Krayonnz   2019.0   Bangalore              EdTech
# 2     PadCare Labs   2018.0        Pune  Hygiene management
# 3            NCOME   2020.0   New Delhi              Escrow
# 4       Gramophone   2016.0      Indore            AgriTech
# ...            ...      ...         ...                 ...
# 1050  Leverage Edu      NaN       Delhi              Edtech
# 1051         EpiFi      NaN        None             Fintech
# 1052       Purplle   2012.0      Mumbai           Cosmetics
# 1053        Shuttl   2015.0       Delhi           Transport
# 1054         Pando   2017.0     Chennai            Logitech
#
#                                            What_it_does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# 3                          Escrow-as-a-service platform
# 4     Gramophone is an AgTech platform enabling acce...
# ...                                                 ...
# 1050  AI enabled marketplace that provides career gu...
# 1051  It offers customers with a single interface fo...
# 1052         Online makeup and beauty products retailer
# 1053                    App based bus aggregator serice
# 1054            Networked logistics management software
#
#                                                Founders  \
# 0                       Prasanna Manogaran, Bharani C L
# 1                      Saurabh Dixit, Gurudutt Upadhyay
# 2                                       Ajinkya Dhariya
# 3                                         Ritesh Tiwari
# 4     Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# ...                                                 ...
# 1050                                  Akshay Chaturvedi
# 1051                    Sujith Narayanan, Sumit Gwalani
# 1052                          Manish Taneja, Rahul Dash
# 1053                      Amit Singh, Deepanshu Malviya
# 1054                     Jayakrishnan, Abhijeet Manohar
#
#                                    Investor      Amount       Stage column10
# 0                           Angel investors    200000.0        None     None
# 1                           GSF Accelerator    100000.0    Pre-seed     None
# 2                            Venture Center         NaN    Pre-seed     None
# 3       Venture Catalysts, PointOne Capital    400000.0        None     None
# 4       Siana Capital Management, Info Edge    340000.0        None     None
# ...                                     ...         ...         ...      ...
# 1050  DSG Consumer Partners, Blume Ventures   1500000.0        None     None
# 1051          Sequoia India, Ribbit Capital  13200000.0  Seed Round     None
# 1052                             Verlinvest   8000000.0        None     None
# 1053             SIG Global India Fund LLP.   8043000.0    Series C     None
# 1054                      Chiratae Ventures   9000000.0    Series A     None
#
# [1055 rows x 10 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1055 non-null   object
#  1   Founded        842 non-null    float64
#  2   HeadQuarter    961 non-null    object
#  3   Sector         1042 non-null   object
#  4   What_it_does   1055 non-null   object
#  5   Founders       1043 non-null   object
#  6   Investor       1017 non-null   object
#  7   Amount         801 non-null    float64
#  8   Stage          591 non-null    object
#  9   column10       2 non-null      object
# dtypes: float64(2), object(8)
# memory usage: 82.6+ KB
#
# DataFrame after filling null values with 'N/A':
#      Company_Brand  Founded HeadQuarter              Sector  \
# 0       Aqgromalin     2019     Chennai            AgriTech
# 1         Krayonnz     2019   Bangalore              EdTech
# 2     PadCare Labs     2018        Pune  Hygiene management
# 3            NCOME     2020   New Delhi              Escrow
# 4       Gramophone     2016      Indore            AgriTech
# ...            ...      ...         ...                 ...
# 1050  Leverage Edu        0       Delhi              Edtech
# 1051         EpiFi        0         N/A             Fintech
# 1052       Purplle     2012      Mumbai           Cosmetics
# 1053        Shuttl     2015       Delhi           Transport
# 1054         Pando     2017     Chennai            Logitech
#
#                                            What_it_does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# 3                          Escrow-as-a-service platform
# 4     Gramophone is an AgTech platform enabling acce...
# ...                                                 ...
# 1050  AI enabled marketplace that provides career gu...
# 1051  It offers customers with a single interface fo...
# 1052         Online makeup and beauty products retailer
# 1053                    App based bus aggregator serice
# 1054            Networked logistics management software
#
#                                                Founders  \
# 0                       Prasanna Manogaran, Bharani C L
# 1                      Saurabh Dixit, Gurudutt Upadhyay
# 2                                       Ajinkya Dhariya
# 3                                         Ritesh Tiwari
# 4     Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# ...                                                 ...
# 1050                                  Akshay Chaturvedi
# 1051                    Sujith Narayanan, Sumit Gwalani
# 1052                          Manish Taneja, Rahul Dash
# 1053                      Amit Singh, Deepanshu Malviya
# 1054                     Jayakrishnan, Abhijeet Manohar
#
#                                    Investor      Amount       Stage column10
# 0                           Angel investors    200000.0         N/A     None
# 1                           GSF Accelerator    100000.0    Pre-seed     None
# 2                            Venture Center         NaN    Pre-seed     None
# 3       Venture Catalysts, PointOne Capital    400000.0         N/A     None
# 4       Siana Capital Management, Info Edge    340000.0         N/A     None
# ...                                     ...         ...         ...      ...
# 1050  DSG Consumer Partners, Blume Ventures   1500000.0         N/A     None
# 1051          Sequoia India, Ribbit Capital  13200000.0  Seed Round     None
# 1052                             Verlinvest   8000000.0         N/A     None
# 1053             SIG Global India Fund LLP.   8043000.0    Series C     None
# 1054                      Chiratae Ventures   9000000.0    Series A     None
#
# [1055 rows x 10 columns]
#
# DataFrame after processing:
#   Company_Brand  Founded HeadQuarter               Sector  \
# 0    Aqgromalin     2019     Chennai             AgriTech
# 1      Krayonnz     2019   Bangalore               EdTech
# 2  PadCare Labs     2018        Pune   Hygiene management
# 3         NCOME     2020   New Delhi               Escrow
# 4    Gramophone     2016      Indore             AgriTech
# 5        qZense     2019   Bangalore             AgriTech
# 6  MyClassboard     2008   Hyderabad               EdTech
# 7         Metvy     2018     Gurgaon  Networking platform
# 8        Rupeek     2015   Bangalore              FinTech
# 9     Gig India     2017        Pune        Crowdsourcing
#
#                                         What_it_does  \
# 0                       Cultivating Ideas for Profit
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
# 5  qZense Labs is building the next-generation Io...
# 6  MyClassboard is a full-fledged School / Colleg...
# 7  AI driven networking platform for individuals ...
# 8  Rupeek is an online lending platform that spec...
# 9  GigIndia is a marketplace that provides on-dem...
#
#                                             Founders  \
# 0                    Prasanna Manogaran, Bharani C L
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# 5                       Rubal Chib, Dr Srishti Batra
# 6                                     Ajay Sakhamuri
# 7                                   Shawrya Mehrotra
# 8            Amar Prabhu, Ashwin Soni, Sumit Maniyar
# 9                       Aditya Shirole, Sahil Sharma
#
#                                         Investor    Amount         Stage  \
# 0                                Angel investors    200000           N/A
# 1                                GSF Accelerator    100000      Pre-seed
# 2                                 Venture Center         0      Pre-seed
# 3            Venture Catalysts, PointOne Capital    400000           N/A
# 4            Siana Capital Management, Info Edge    340000           N/A
# 5  Venture Catalysts, 9Unicorns Accelerator Fund    600000          Seed
# 6                                    ICICI Bank.    600000  Pre-series A
# 7                                     HostelFund         0    Pre-series
# 8   KB Investment, Bertelsmann India Investments  45000000      Series C
# 9      Shantanu Deshpande, Subramaniam Ramadorai   1000000  Pre-series A
#
#   column10
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None

# %%
#dropping column 10
final_2020=cleandata_2020.drop('column10', axis=1)
final_2020
# Out:
#      Company_Brand  Founded HeadQuarter              Sector  \
# 0       Aqgromalin     2019     Chennai            AgriTech
# 1         Krayonnz     2019   Bangalore              EdTech
# 2     PadCare Labs     2018        Pune  Hygiene management
# 3            NCOME     2020   New Delhi              Escrow
# 4       Gramophone     2016      Indore            AgriTech
# ...            ...      ...         ...                 ...
# 1050  Leverage Edu        0       Delhi              Edtech
# 1051         EpiFi        0         N/A             Fintech
# 1052       Purplle     2012      Mumbai           Cosmetics
# 1053        Shuttl     2015       Delhi           Transport
# 1054         Pando     2017     Chennai            Logitech
#
#                                            What_it_does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# 3                          Escrow-as-a-service platform
# 4     Gramophone is an AgTech platform enabling acce...
# ...                                                 ...
# 1050  AI enabled marketplace that provides career gu...
# 1051  It offers customers with a single interface fo...
# 1052         Online makeup and beauty products retailer
# 1053                    App based bus aggregator serice
# 1054            Networked logistics management software
#
#                                                Founders  \
# 0                       Prasanna Manogaran, Bharani C L
# 1                      Saurabh Dixit, Gurudutt Upadhyay
# 2                                       Ajinkya Dhariya
# 3                                         Ritesh Tiwari
# 4     Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# ...                                                 ...
# 1050                                  Akshay Chaturvedi
# 1051                    Sujith Narayanan, Sumit Gwalani
# 1052                          Manish Taneja, Rahul Dash
# 1053                      Amit Singh, Deepanshu Malviya
# 1054                     Jayakrishnan, Abhijeet Manohar
#
#                                    Investor    Amount       Stage
# 0                           Angel investors    200000         N/A
# 1                           GSF Accelerator    100000    Pre-seed
# 2                            Venture Center         0    Pre-seed
# 3       Venture Catalysts, PointOne Capital    400000         N/A
# 4       Siana Capital Management, Info Edge    340000         N/A
# ...                                     ...       ...         ...
# 1050  DSG Consumer Partners, Blume Ventures   1500000         N/A
# 1051          Sequoia India, Ribbit Capital  13200000  Seed Round
# 1052                             Verlinvest   8000000         N/A
# 1053             SIG Global India Fund LLP.   8043000    Series C
# 1054                      Chiratae Ventures   9000000    Series A
#
# [1055 rows x 9 columns]

# %%
final_2020.isna().sum()
# Out:
# Company_Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# What_it_does     0
# Founders         0
# Investor         0
# Amount           0
# Stage            0
# dtype: int64

# %% [markdown]
# **Cleaning 2021 data**

# %%
df_2021.head()
# Out:
#     Company_Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics   2019.0   Bangalore      AI startup
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor        Amount         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000          None
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed

# %%
def swap_non_numeric_with_numeric(df):
    amounts_column = 'Amount'
    stage_column = 'Stage'
    investor_column = 'Investor'
 
    # Function to find non-numeric values in 'Amounts' column
    def find_non_numeric_values():
        non_numeric_dict = {}
        for index, value in df[amounts_column].items():
            try:
                pd.to_numeric(value)
            except ValueError:
                non_numeric_dict[index] = value
        return non_numeric_dict
 
    # Function to find numeric values in 'Stage' column
    def find_numeric_values():
        numeric_dict = {}
        for index, value in df[stage_column].items():
            try:
                numeric_dict[index] = pd.to_numeric(value)
            except ValueError:
                pass  # Ignore non-numeric values
        return numeric_dict
 
    # Find non-numeric values in 'Amounts' column
    non_numeric_values = find_non_numeric_values()
 
    # Find numeric values in 'Stage' column
    numeric_values = find_numeric_values()
 
    # Swap non-numeric values in 'Amounts' with numeric values in 'Stage'
    for index, non_numeric_value in non_numeric_values.items():
        if index in numeric_values:
            df.at[index, amounts_column] = numeric_values[index]
 
    # Swap numeric values in 'Stage' with non-numeric values in 'Amounts'
    for index, numeric_value in numeric_values.items():
        if index in non_numeric_values:
            df.at[index, stage_column] = non_numeric_values[index]
 
    # Function to find numeric values in 'Investor' column
    def find_numeric_values_founders():
        numeric_dict = {}
        for index, value in df[investor_column].items():
            try:
                numeric_dict[index] = pd.to_numeric(value)
            except ValueError:
                pass  # Ignore non-numeric values
        return numeric_dict
 
    # Function to find non-numeric values in 'Amounts' column
    def find_non_numeric_values_founders():
        non_numeric_dict = {}
        for index, value in df[amounts_column].items():
            try:
                pd.to_numeric(value)
            except ValueError:
                non_numeric_dict[index] = value
        return non_numeric_dict
 
    # Find non-numeric values in 'Amounts' column
    non_numeric_values = find_non_numeric_values_founders()
 
    # Find numeric values in 'Founders' column
    numeric_values = find_numeric_values_founders()
 
    # Swap non-numeric values in 'Amounts' with numeric values in 'Founders'
    for index, non_numeric_value in non_numeric_values.items():
        if index in numeric_values:
            df.at[index, amounts_column] = numeric_values[index]
 
    # Swap numeric values in 'Founders' with non-numeric values in 'Amounts'
    for index, numeric_value in numeric_values.items():
        if index in non_numeric_values:
            df.at[index, investor_column] = non_numeric_values[index]
 
    return df
 
 
def strip_dollar_and_comma(df):
    # Assuming column names are 'Amounts' and 'Stage'
    numeric_columns = ['Investor', 'Amount', 'Stage']
 
    # Iterate through numeric columns and strip dollar sign ($) and comma (,)
    for column in numeric_columns:
        df[column] = df[column].replace('[\$ ,]', '', regex=True)
 
    return df
 
 
def replace_non_numeric_with_zero(df):
    # Assuming column name is 'Amounts'
    amounts_column = 'Amount'
    # Replace non-numeric values in 'Amounts' column with 0
    df[amounts_column] = pd.to_numeric(df[amounts_column], errors='coerce').fillna(0).astype(int)
 
    return df


def fill_null_values(df):
    # Specify the columns to fill with 'N/A'
    columns_to_fill_na = ['HeadQuarter', 'Investor', 'Stage','Sector']
 
    # Fill null values in specified columns with 'N/A'
    df[columns_to_fill_na] = df[columns_to_fill_na].fillna('N/A')

    # Fill null values in 'Founded' with 0   
    df['Founded'] = df['Founded'].fillna(0)

    # Convert 'Founded' values to integers    
    df['Founded'] = df['Founded'].astype(int)
 
    return df


  
 
# Example usage
#data = {'Founders': ['$1,200', '$1,300,000', '', 'D', 'E', 'F', '', 'H', 'J', 'K'],
       # 'Amounts': ['A', 'Undisclosed', '$4,000', '$5,000', 'undisclosed', '$7,000,000', 'Seed', '$4,000', 'series A', '$5,000'],
       # 'Stage': ['Upsparks', 'Series C', 'series c', 'seed', 'seed', 'seed', '$2,000', 'seed', '$3,000', 'series A']}
df = pd.DataFrame(df_2021)
 
# Display the DataFrame before processing
print("DataFrame before processing:")
print(df)
info = df.info()
#print("\n Info before processing")
#print(info)
 
# Call the function to replace NaN values in 'Founders' with "N/A"
df['Founders'] = df['Founders'].fillna('N/A')
 
# Call the function to strip dollar sign and comma from numeric values
df = strip_dollar_and_comma(df)
 
# Display the DataFrame after stripping dollar sign and comma
#print("\nDataFrame after stripping dollar sign and comma:")
#print(df)
 
# Call the function to swap non-numeric with numeric values
df = swap_non_numeric_with_numeric(df)
 
# Display the DataFrame after swapping Numerical values in Stage with non-numericals in amounts
#print("\nDataFrame after swapping numeric in 'Stage' with non-numeric values in 'Amount':")
#print(df)
 
# Call the function to swap numeric with non-numeric values in 'Founders'
df = swap_non_numeric_with_numeric(df)
 
# Display the DataFrame after swapping numeric with non-numeric values in 'Founders'
#print("\nDataFrame after swapping numeric in 'Founders' with non-numeric values in 'Amount':")
#print(df)
# Call the function to fill null values with 'N/A'
df = fill_null_values(df)
 # Display the DataFrame after filling null values
print("\nDataFrame after filling null values with 'N/A':")

print(df)
# Call the function to replace non-numeric values in 'Amounts' with 0
df = replace_non_numeric_with_zero(df)

# Call the function to fill null values in  'Founded' with 0
df = fill_null_values(df) 
# Display the DataFrame after filling null values
#print("\nDataFrame after filling null values with 'N/A' and 'Founded' with 0:")
#print(df)

 
 
# Display the DataFrame after replacing non-numeric values with 0
#My amounts column should have all numerics
#print("\nDataFrame after replacing non-numeric values with 0 :")
print("\nDataFrame after processing:")
cleandata_2021=df
cleandata_2021.head(10)
# Out:
# DataFrame before processing:
#        Company_Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics   2019.0   Bangalore             AI startup
# 1             upGrad   2015.0      Mumbai                 EdTech
# 2        Lead School   2012.0      Mumbai                 EdTech
# 3            Bizongo   2015.0      Mumbai         B2B E-commerce
# 4           FypMoney   2021.0    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1205          Vahdam   2015.0   New Delhi       Food & Beverages
# 1206    Leap Finance   2019.0   Bangalore     Financial Services
# 1207    CollegeDekho   2015.0    Gurugram                 EdTech
# 1208          WeRize   2019.0   Bangalore     Financial Services
#
#                                            What_it_does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# 2     LEAD School offers technology based school tra...
# 3     Bizongo is a business-to-business online marke...
# 4     FypMoney is Digital NEO Bank for Teenagers, em...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                                Founders  \
# 0                           Pramod Ghadge, Shahid Memon
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                            Smita Deorah, Sumeet Mehta
# 3               Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                         Kapil Banwari
# ...                                                 ...
# 1204                        Chirag Mittal, Anirudh Syal
# 1205                                         Bala Sarda
# 1206                         Arnav Kumar, Vaibhav Singh
# 1207                                       Ruchir Arora
# 1208                      Vishal Chopra, Himanshu Gupta
#
#                                            Investor        Amount  \
# 0                       BEENEXT, Entrepreneur First    $1,200,000
# 1          Unilazer Ventures, IIFL Asset Management  $120,000,000
# 2                  GSV Ventures, Westbridge Capital   $30,000,000
# 3                            CDC Group, IDG Capital   $51,000,000
# 4     Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000
# ...                                             ...           ...
# 1204                                Endiya Partners      $3000000
# 1205                                       IIFL AMC     $20000000
# 1206                                   Owl Ventures     $55000000
# 1207               Winter Capital, ETS, Man Capital     $26000000
# 1208                 3one4 Capital, Kalaari Capital      $8000000
#
#              Stage
# 0     Pre-series A
# 1             None
# 2         Series D
# 3         Series C
# 4             Seed
# ...            ...
# 1204  Pre-series A
# 1205      Series D
# 1206      Series C
# 1207      Series B
# 1208      Series A
#
# [1209 rows x 9 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company_Brand  1209 non-null   object
#  1   Founded        1208 non-null   float64
#  2   HeadQuarter    1208 non-null   object
#  3   Sector         1209 non-null   object
#  4   What_it_does   1209 non-null   object
#  5   Founders       1205 non-null   object
#  6   Investor       1147 non-null   object
#  7   Amount         1206 non-null   object
#  8   Stage          781 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 85.1+ KB
#
# DataFrame after filling null values with 'N/A':
#        Company_Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics     2019   Bangalore             AI startup
# 1             upGrad     2015      Mumbai                 EdTech
# 2        Lead School     2012      Mumbai                 EdTech
# 3            Bizongo     2015      Mumbai         B2B E-commerce
# 4           FypMoney     2021    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce     2019    Gurugram  Staffing & Recruiting
# 1205          Vahdam     2015   New Delhi       Food & Beverages
# 1206    Leap Finance     2019   Bangalore     Financial Services
# 1207    CollegeDekho     2015    Gurugram                 EdTech
# 1208          WeRize     2019   Bangalore     Financial Services
#
#                                            What_it_does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# 2     LEAD School offers technology based school tra...
# 3     Bizongo is a business-to-business online marke...
# 4     FypMoney is Digital NEO Bank for Teenagers, em...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                                Founders  \
# 0                           Pramod Ghadge, Shahid Memon
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                            Smita Deorah, Sumeet Mehta
# 3               Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                         Kapil Banwari
# ...                                                 ...
# 1204                        Chirag Mittal, Anirudh Syal
# 1205                                         Bala Sarda
# 1206                         Arnav Kumar, Vaibhav Singh
# 1207                                       Ruchir Arora
# 1208                      Vishal Chopra, Himanshu Gupta
#
#                                     Investor     Amount        Stage
# 0                   BEENEXTEntrepreneurFirst    1200000  Pre-seriesA
# 1        UnilazerVenturesIIFLAssetManagement  120000000          N/A
# 2               GSVVenturesWestbridgeCapital   30000000      SeriesD
# 3                         CDCGroupIDGCapital   51000000      SeriesC
# 4     LiberathaKallatMukeshYadavDineshNagpal    2000000         Seed
# ...                                      ...        ...          ...
# 1204                          EndiyaPartners    3000000  Pre-seriesA
# 1205                                 IIFLAMC   20000000      SeriesD
# 1206                             OwlVentures   55000000      SeriesC
# 1207              WinterCapitalETSManCapital   26000000      SeriesB
# 1208              3one4CapitalKalaariCapital    8000000      SeriesA
#
# [1209 rows x 9 columns]
#
# DataFrame after processing:
#     Company_Brand  Founded HeadQuarter          Sector  \
# 0  Unbox Robotics     2019   Bangalore      AI startup
# 1          upGrad     2015      Mumbai          EdTech
# 2     Lead School     2012      Mumbai          EdTech
# 3         Bizongo     2015      Mumbai  B2B E-commerce
# 4        FypMoney     2021    Gurugram         FinTech
# 5   Urban Company     2014   New Delhi   Home services
# 6  Comofi Medtech     2018   Bangalore      HealthTech
# 7     Qube Health     2016      Mumbai      HealthTech
# 8        Vitra.ai     2020   Bangalore    Tech Startup
# 9          Taikee     2010      Mumbai      E-commerce
#
#                                         What_it_does  \
# 0  Unbox Robotics builds on-demand AI-driven ware...
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
# 5  Urban Company (Formerly UrbanClap) is a home a...
# 6   Comofi Medtech is a healthcare robotics startup.
# 7  India's Most Respected Workplace Healthcare Ma...
# 8  Vitra.ai is an AI-based video translation plat...
# 9  Taikee is the ISO-certified, B2B e-commerce pl...
#
#                                             Founders  \
# 0                        Pramod Ghadge, Shahid Memon
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
# 5  Abhiraj Singh Bhal, Raghav Chandra, Varun Khaitan
# 6                                         Gururaj KB
# 7                                        Gagan Kapur
# 8                                     Akash Nidhi PS
# 9                 Nidhi Ramachandran, Sachin Chhabra
#
#                                  Investor     Amount        Stage
# 0                BEENEXTEntrepreneurFirst    1200000  Pre-seriesA
# 1     UnilazerVenturesIIFLAssetManagement  120000000          N/A
# 2            GSVVenturesWestbridgeCapital   30000000      SeriesD
# 3                      CDCGroupIDGCapital   51000000      SeriesC
# 4  LiberathaKallatMukeshYadavDineshNagpal    2000000         Seed
# 5                               VyCapital  188000000          N/A
# 6                         CIIE.COKIIT-TBI     200000          N/A
# 7                 InflectionPointVentures          0  Pre-seriesA
# 8                        InflexorVentures          0  Undisclosed
# 9                                     N/A    1000000          N/A

# %%
#checking for nulls
cleandata_2021.isna().sum()
# Out:
# Company_Brand    0
# Founded          0
# HeadQuarter      0
# Sector           0
# What_it_does     0
# Founders         0
# Investor         0
# Amount           0
# Stage            0
# dtype: int64
